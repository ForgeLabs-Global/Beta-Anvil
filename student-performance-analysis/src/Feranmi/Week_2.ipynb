# %%
#writing functions
#declaring function 
def welcome():
    print("Welcome to Forge labs")
#executing function
welcome()
# Out:
# Welcome to Forge labs

# %%
#parameters and returning values
#declaring function
def add_numbers(a, b):
    return a + b
#executing function 
result = add_numbers(5, 3)
#output result
print(result)
# Out:
# 8

# %%
#parameters and returning values
#declaring function
def square_number(a):
    return a * a
#executing function 
result = square_number(5)
#output result
print(result)
# Out:
# 25

# %%
#creating list
fruits = ["apple", "banana", "orange", "mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
import pandas as pd

#load students performance dataset
data = pd.read_csv(r"C:\Users\USER\Desktop\Forgelabs\res\data\StudentsPerformance.csv")
#init. var type list 
FirstTenScores = data["math score"][:10].tolist()
list = FirstTenScores
print(list)
# Out:
# [72, 69, 90, 47, 76, 71, 88, 40, 64, 38]

# %%
#add 100 to list 
list.append(100)
print(list)
# Out:
# [72, 69, 90, 47, 76, 71, 88, 40, 64, 38, 100]

# %%
#remove 100 from list 
list.remove(100)
print(list)
# Out:
# [72, 69, 90, 47, 76, 71, 88, 40, 64, 38]

# %%
#iterate through list
for number in list:
    print("Number:", number)
# Out:
# Number: 72
# Number: 69
# Number: 90
# Number: 47
# Number: 76
# Number: 71
# Number: 88
# Number: 40
# Number: 64
# Number: 38

# %%
#declare a function that finds the sum of items in list
def sum_list(list):
    total = 0

    for number in list:
        total = total + number

    return total

print(sum_list(list))
# Out:
# 655
