# %% [markdown]
# # Beta Anvil — Week 3
#
# # How To Use This Notebook
#
# 1. Do not try to complete every task.
# 2. Open the Beta Anvil Sprint Board.
# 3. Find your assigned task.
# 4. Complete only the section related to your task.
# 5. You can also optionally decide to delete the other parts that are related to you
#
# ## Loops and Dataset Exploration
#
# In Week 2 we learned:
#
# • Lists
# • Functions
#
# These tools allow us to organize logic and store multiple values.
#
# This week we learn something extremely important in programming:
#
# LOOPS.
#
# A loop allows us to go through many pieces of data automatically.
#
# Why this matters for data science:
#
# Datasets often contain hundreds or thousands of rows.
# Manually checking each row is impossible.
#
# Loops allow a program to inspect every row quickly.

# %% [markdown]
# ## Load the Dataset
#
# We are continuing with the **Student Performance Dataset**.
#
# This dataset contains exam results for many students.
#
# Important columns include:
#
# • gender
# • math score
# • reading score
# • writing score

# %%
import pandas as pd

data = pd.read_csv("../../data/StudentsPerformance.csv") #replace the -- with you dataset file path

data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# The table above shows the first few rows.
#
# Each row represents **one student**.

# %% [markdown]
# A dataset column contains many values.
#
# For example:
#
# The **math score column** contains the math score of every student.
#
# We can extract a column like this:

# %%
math_scores = data["math score"]

math_scores.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %% [markdown]
# What happened here?
#
# 1. We selected the column.
# 2. We converted it into a list.
# 3. Now we can loop through it easily.

# %% [markdown]
# ## Understanding Loops
#
# A loop allows us to repeat an action many times.
#
# Example:
#
# If we have a list of scores, we can inspect each score one by one.

# %%
scores = [72, 69, 90, 47]

for score in scores:
    print(score)
# Out:
# 72
# 69
# 90
# 47

# %% [markdown]
# What this code does:
#
# • `for score in scores` means:
#   take each value in the list one at a time.
#
# • `print(score)` displays each value.
#
# The loop continues until every value has been checked.

# %% [markdown]
# Now let's apply loops to the dataset.
#
# Suppose we want to count how many students scored above 80 in math.
#
# We can inspect every score using a loop.

# %%
count = 0

for score in math_list:
    
    # check if score meets a condition
    
    # increase the counter if true

print(count)
# Out:
#   Cell In[10], line 9
#     print(count)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %% [markdown]
# Our project is **Student Performance Analysis**.
#
# To understand student performance we must answer questions like:
#
# • How many students passed math?
# • What is the highest score?
# • What is the average score?
# • Are some groups performing better?
#
# Loops help us inspect the data and compute these answers.

# %% [markdown]
# These tasks help you practice using loops with lists.

# %% [markdown]
# # Junior task
# ### Task 1 — Count High Math Scores
# Create a function that counts how many students scored **above 80 in math**.
#
# Hints:
#
# • extract the math scores into a list
# • use a loop
# • use a counter variable

# %%
# extract the math scores into a list
math_scores = data["math score"].to_list()

# Creating function to take math score list
def high_scores(math_scores):
    
    counter = 0    # setting initial counter value to 0
    
    # looping through math scores
    for score in math_scores:
        # adding condition for high score
        if score > 80:  
            counter += 1
        else:
            pass
        
    # output the final counter value
    return counter

# testing function
high_scores(math_scores)
# Out:
# 176

# %% [markdown]
# ### Task 2 — Find the Lowest Score

# %% [markdown]
# Create a function that finds the **lowest math score**.
#
# Hints:
#
# • start with a variable storing a value
# • loop through the list
# • update the variable when a smaller value is found

# %%
# Write your function here

# %% [markdown]
# # 🔹 Core Analyst Tasks

# %% [markdown]
# ### Task 1 — Score Distribution

# %% [markdown]
# Create a function that separates math scores into two groups:
#
# • scores above 70
# • scores 70 and below
#
# Hints:
#
# • create two lists
# • loop through math scores
# • append scores to the appropriate list

# %%
# Write your function here

# %% [markdown]
# ### Task 2 — Gender Performance Investigation

# %% [markdown]
# Create a function that compares math scores between genders.
#
# Hints:
#
# • filter rows by gender
# • store scores in lists
# • compute averages

# %%
# Write your function here

# %% [markdown]
# Before Friday:
#
# 1. Complete your assigned task.
# 2. Test your function.
# 3. Save the notebook.
# 4. Push it to your GitHub folder.
#
# Minimum commits required: 3
#
# Remember:
#
# If it is not on GitHub, it does not exist.
