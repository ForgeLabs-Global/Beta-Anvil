# %%
import pandas as pd

# Load the student performance dataset
pd.read_csv(r"C:\Users\HP\Documents\GitHub\Beta-Anvil\student-performance-analysis\data\StudentsPerformance.csv")
# Preview the first 5 rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# from the responsibility given to me the first thing is to load the data set

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\HP\Documents\GitHub\Beta-Anvil\student-performance-analysis\data\StudentsPerformance.csv")

data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
math_scores = data["math score"].tolist()

# %%
def separate_scores(scores):

    above_70 = []
    below_or_equal_70 = []

    for score in scores:

        if score > 70:
            above_70.append(score)
        else:
            below_or_equal_70.append(score)

    return above_70, below_or_equal_70

# %%
high_scores, low_scores = separate_scores(math_scores)

print("Scores above 70:", high_scores[:10])
print("Scores 70 and below:", low_scores[:10])
# Out:
# Scores above 70: [72, 90, 76, 71, 88, 78, 88, 74, 73, 97]
# Scores 70 and below: [69, 47, 40, 64, 38, 58, 40, 65, 50, 69]

# %%
high_scores, low_scores = separate_scores(math_scores)

print("Scores above 70:", high_scores[:10])
print("Scores 70 and below:", low_scores[:10])
# Out:
# Scores above 70: [72, 90, 76, 71, 88, 78, 88, 74, 73, 97]
# Scores 70 and below: [69, 47, 40, 64, 38, 58, 40, 65, 50, 69]

# %%
for score in scores:
    # Add your code here
    print(score)  # This is just an example action
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for score in scores:
#       2     # Add your code here
#       3     print(score)  # This is just an example action
#
# NameError: name 'scores' is not defined

# %%
if score > 70:

# %%
else:
    below_or_equal_70.append(score)

# %%
return above_70, below_or_equal_70
# Out:
#   Cell In[2], line 1
#     return above_70, below_or_equal_70
#     ^
# SyntaxError: 'return' outside function
